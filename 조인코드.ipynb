# %%
import pandas as pd
df1=pd.read_csv("ID.csv")
df2=pd.read_csv("LN.csv")
df3=pd.read_csv("DLQ.csv")
df4=pd.read_csv("CD_OPN.csv")

# %%
df4
# Out:
#              YM                                           JOIN_KEY  \
# 0        201612  00000EF019780ACC6BF94255D894F8DC9B7A7B42DD0199...
# 1        201612  00000EF019780ACC6BF94255D894F8DC9B7A7B42DD0199...
# 2        201701  00000EF019780ACC6BF94255D894F8DC9B7A7B42DD0199...
# 3        201701  00000EF019780ACC6BF94255D894F8DC9B7A7B42DD0199...
# 4        201702  00000EF019780ACC6BF94255D894F8DC9B7A7B42DD0199...
# ...         ...                                                ...
# 2608295  201811  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...
# 2608296  201811  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...
# 2608297  201812  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...
# 2608298  201812  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...
# 2608299  201812  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...
#
#                                                    COM_KEY  CD_OPN_CD_1  \
# 0        0C8CFA9DFF0A43CC97219B64CC3B9A5E8A22BC060F496B...           81
# ...

# %%
df12=pd.merge(df1,df2)
df12
# Out:
#                                                   JOIN_KEY  BTH_YR  GENDER  \
# 0        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 1        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 2        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 3        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 4        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# ...                                                    ...     ...     ...
# 1407667  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1407668  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1407669  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1407670  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1407671  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
#
# ...

# %%
df123=pd.merge(df12,df3,on=('JOIN_KEY','YM',"COM_KEY"),how='left')
df123
# Out:
#                                                   JOIN_KEY  BTH_YR  GENDER  \
# 0        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 1        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 2        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 3        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 4        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# ...                                                    ...     ...     ...
# 1417040  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1417041  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1417042  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1417043  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1417044  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
#
# ...

# %%
df1234=pd.merge(df123,df4,on=("YM","JOIN_KEY","COM_KEY"),how="left")
df1234
# Out:
#                                                   JOIN_KEY  BTH_YR  GENDER  \
# 0        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 1        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 2        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 3        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# 4        00001661E0334575AEC81C35FE161FC00C69218BFEE9E1...    1957       2
# ...                                                    ...     ...     ...
# 1470022  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1470023  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1470024  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1470025  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
# 1470026  073412EE52D5FDBF40B7E0E97B89DE15A2491B484224AB...    1971       1
#
# ...

# %%
df1234.to_csv("JOIN_F.csv",index=False)

# %%
df1234.to_excel("JOIN_F.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-c3b05f9c798a> in <module>
# ----> 1 df1234.to_excel("JOIN_F.xlsx",index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2024             inf_rep=inf_rep,
#    2025         )
# -> 2026         formatter.write(
#    2027             excel_writer,
#    2028             sheet_name=sheet_name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     720         num_rows, num_cols = self.df.shape
#     721         if num_rows > self.max_rows or num_cols > self.max_cols:
# ...
